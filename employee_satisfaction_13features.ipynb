# %%
# Importing numpy and pandas
import numpy as np
import pandas as pd

# Importing plot libraries
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
sns.set_style('whitegrid')

# %%
# Import employee survey dataset
df = pd.read_csv('public-sector-commission-eps-2016and2015.csv')
df
# Out:
#       job_satisfaction_level  level_of_skill_used  expectations_clarity  \
# 0                          2                    1                     1
# 1                          1                    1                     1
# 2                          6                    3                     3
# 3                          7                    7                     7
# 4                          7                    5                     7
# ...                      ...                  ...                   ...
# 4079                       7                    4                     4
# 4080                       6                    2                     1
# 4081                       6                    4                     4
# 4082                       5                    3                     3
# 4083                       6                    1                     1
#
#       contribution_recognition  career_development  well_managed  \
# 0                            1                   3             6
# 1                            1                   1             1
# 2                            4                   4             7
# 3                            7                   7             7
# 4                            5                   7             6
# ...                        ...                 ...           ...
# 4079                         7                   7             7
# 4080                         6                   3             2
# 4081                         7                   7             6
# 4082                         5                   5             2
# 4083                         7                   7             6
#
#       worklife_balance  effective_communication  respectful_supervisor  \
# 0                    3                        2                      1
# 1                    1                        1                      1
# 2                    2                        7                      2
# 3                    7                        7                      7
# 4                    3                        7                      1
# ...                ...                      ...                    ...
# 4079                 7                        7                      4
# 4080                 3                        2                      1
# 4081                 5                        4                      4
# 4082                 5                        5                      5
# 4083                 7                        7                      3
#
#       good_relationship_with_coworkers  ethical_practices  \
# 0                                    1                  1
# 1                                    1                  1
# 2                                    4                  3
# 3                                    7                  2
# 4                                    1                  2
# ...                                ...                ...
# 4079                                 4                  5
# 4080                                 1                  2
# 4081                                 1                  2
# 4082                                 5                  3
# 4083                                 3                  1
#
#       conflicts_immediately_resolved  education_level  salary_rate
# 0                                  4                2            4
# 1                                  1                2            3
# 2                                  7                1            3
# 3                                  7                1            2
# 4                                  6                1            2
# ...                              ...              ...          ...
# 4079                               4                2            4
# 4080                               2                2            2
# 4081                               6                1            2
# 4082                               3                2            1
# 4083                               1                2            3
#
# [4084 rows x 14 columns]

# %%
# Agreeable level that employee is satisfied with their job.
# 1 for Strongly agree and 7 for Strongly disagree.

df['job_satisfaction_level'].value_counts()
# Out:
# 2    1300
# 1     871
# 5     604
# 3     520
# 6     503
# 7     286
# Name: job_satisfaction_level, dtype: int64

# %%
df.columns
# Out:
# Index(['job_satisfaction_level', 'level_of_skill_used', 'expectations_clarity',
#        'contribution_recognition', 'career_development', 'well_managed',
#        'worklife_balance', 'effective_communication', 'respectful_supervisor',
#        'good_relationship_with_coworkers', 'ethical_practices',
#        'conflicts_immediately_resolved', 'education_level', 'salary_rate'],
#       dtype='object')

# %%
# Ratings except education_level and salary_rate originally reversed: 1 -> 7 = Best -> worst 
# Changing to 1 -> 7 as from worst to best

df2 = df[['job_satisfaction_level','level_of_skill_used', 'expectations_clarity','contribution_recognition', 
          'career_development', 'well_managed','worklife_balance', 'effective_communication', 'respectful_supervisor',
          'good_relationship_with_coworkers', 'ethical_practices',
           'conflicts_immediately_resolved']].replace({1:7,2:6,3:5,4:4,5:3,6:2,7:1})

df2.head()
# Out:
#    job_satisfaction_level  level_of_skill_used  expectations_clarity  \
# 0                       6                    7                     7
# 1                       7                    7                     7
# 2                       2                    5                     5
# 3                       1                    1                     1
# 4                       1                    3                     1
#
#    contribution_recognition  career_development  well_managed  \
# 0                         7                   5             2
# 1                         7                   7             7
# 2                         4                   4             1
# 3                         1                   1             1
# 4                         3                   1             2
#
#    worklife_balance  effective_communication  respectful_supervisor  \
# 0                 5                        6                      7
# 1                 7                        7                      7
# 2                 6                        1                      6
# 3                 1                        1                      1
# 4                 5                        1                      7
#
#    good_relationship_with_coworkers  ethical_practices  \
# 0                                 7                  7
# 1                                 7                  7
# 2                                 4                  5
# 3                                 1                  6
# 4                                 7                  6
#
#    conflicts_immediately_resolved
# 0                               4
# 1                               7
# 2                               1
# 3                               1
# 4                               2

# %%
# Adding columns education_level and salary_rate back in
df2['education_level'] = df['education_level']
df2['salary_rate'] = df['salary_rate']

df2.head()
# Out:
#    job_satisfaction_level  level_of_skill_used  expectations_clarity  \
# 0                       6                    7                     7
# 1                       7                    7                     7
# 2                       2                    5                     5
# 3                       1                    1                     1
# 4                       1                    3                     1
#
#    contribution_recognition  career_development  well_managed  \
# 0                         7                   5             2
# 1                         7                   7             7
# 2                         4                   4             1
# 3                         1                   1             1
# 4                         3                   1             2
#
#    worklife_balance  effective_communication  respectful_supervisor  \
# 0                 5                        6                      7
# 1                 7                        7                      7
# 2                 6                        1                      6
# 3                 1                        1                      1
# 4                 5                        1                      7
#
#    good_relationship_with_coworkers  ethical_practices  \
# 0                                 7                  7
# 1                                 7                  7
# 2                                 4                  5
# 3                                 1                  6
# 4                                 7                  6
#
#    conflicts_immediately_resolved  education_level  salary_rate
# 0                               4                2            4
# 1                               7                2            3
# 2                               1                1            3
# 3                               1                1            2
# 4                               2                1            2

# %%
# Checking if ratings are changed correctly
df.head()
# Out:
#    job_satisfaction_level  level_of_skill_used  expectations_clarity  \
# 0                       2                    1                     1
# 1                       1                    1                     1
# 2                       6                    3                     3
# 3                       7                    7                     7
# 4                       7                    5                     7
#
#    contribution_recognition  career_development  well_managed  \
# 0                         1                   3             6
# 1                         1                   1             1
# 2                         4                   4             7
# 3                         7                   7             7
# 4                         5                   7             6
#
#    worklife_balance  effective_communication  respectful_supervisor  \
# 0                 3                        2                      1
# 1                 1                        1                      1
# 2                 2                        7                      2
# 3                 7                        7                      7
# 4                 3                        7                      1
#
#    good_relationship_with_coworkers  ethical_practices  \
# 0                                 1                  1
# 1                                 1                  1
# 2                                 4                  3
# 3                                 7                  2
# 4                                 1                  2
#
#    conflicts_immediately_resolved  education_level  salary_rate
# 0                               4                2            4
# 1                               1                2            3
# 2                               7                1            3
# 3                               7                1            2
# 4                               6                1            2

# %%
df2.job_satisfaction_level.value_counts()
# Out:
# 6    1300
# 7     871
# 3     604
# 5     520
# 2     503
# 1     286
# Name: job_satisfaction_level, dtype: int64

# %%
# Creating function to classify that the employee likes the job or not like.
def job_satisfaction(x):
    if x >= 5:
        return 1
    else:
        return 0
    
# Adding 'likes_job' column where 0 if employee does not like job and 1 meaning the like their job.
df2['likes_job'] = df2['job_satisfaction_level'].apply(job_satisfaction)

# Check table
df2
# Out:
#       job_satisfaction_level  level_of_skill_used  expectations_clarity  \
# 0                          6                    7                     7
# 1                          7                    7                     7
# 2                          2                    5                     5
# 3                          1                    1                     1
# 4                          1                    3                     1
# ...                      ...                  ...                   ...
# 4079                       1                    4                     4
# 4080                       2                    6                     7
# 4081                       2                    4                     4
# 4082                       3                    5                     5
# 4083                       2                    7                     7
#
#       contribution_recognition  career_development  well_managed  \
# 0                            7                   5             2
# 1                            7                   7             7
# 2                            4                   4             1
# 3                            1                   1             1
# 4                            3                   1             2
# ...                        ...                 ...           ...
# 4079                         1                   1             1
# 4080                         2                   5             6
# 4081                         1                   1             2
# 4082                         3                   3             6
# 4083                         1                   1             2
#
#       worklife_balance  effective_communication  respectful_supervisor  \
# 0                    5                        6                      7
# 1                    7                        7                      7
# 2                    6                        1                      6
# 3                    1                        1                      1
# 4                    5                        1                      7
# ...                ...                      ...                    ...
# 4079                 1                        1                      4
# 4080                 5                        6                      7
# 4081                 3                        4                      4
# 4082                 3                        3                      3
# 4083                 1                        1                      5
#
#       good_relationship_with_coworkers  ethical_practices  \
# 0                                    7                  7
# 1                                    7                  7
# 2                                    4                  5
# 3                                    1                  6
# 4                                    7                  6
# ...                                ...                ...
# 4079                                 4                  3
# 4080                                 7                  6
# 4081                                 7                  6
# 4082                                 3                  5
# 4083                                 5                  7
#
#       conflicts_immediately_resolved  education_level  salary_rate  likes_job
# 0                                  4                2            4          1
# 1                                  7                2            3          1
# 2                                  1                1            3          0
# 3                                  1                1            2          0
# 4                                  2                1            2          0
# ...                              ...              ...          ...        ...
# 4079                               4                2            4          0
# 4080                               6                2            2          0
# 4081                               2                1            2          0
# 4082                               5                2            1          0
# 4083                               7                2            3          0
#
# [4084 rows x 15 columns]

# %%
df2.columns
# Out:
# Index(['job_satisfaction_level', 'level_of_skill_used', 'expectations_clarity',
#        'contribution_recognition', 'career_development', 'well_managed',
#        'worklife_balance', 'effective_communication', 'respectful_supervisor',
#        'good_relationship_with_coworkers', 'ethical_practices',
#        'conflicts_immediately_resolved', 'education_level', 'salary_rate',
#        'likes_job'],
#       dtype='object')

# %%
# Exploratory Data Analysis


fig2 = plt.figure(figsize=(15,25))

# Level of skills the job requires
ax1 = fig2.add_subplot(621)
ax1.set_xlabel('level_of_skill_used')
ax1.set_ylabel('count')
sns.countplot(data = df2, x = 'level_of_skill_used', hue = 'likes_job')

# Clear Expectations
ax2 = fig2.add_subplot(622)
ax2.set_xlabel('expectations_clarity')
ax2.set_ylabel('count')
sns.countplot(data = df2, x = 'expectations_clarity', hue = 'likes_job')

# How often recognized for contributions
ax3 = fig2.add_subplot(623)
ax3.set_xlabel('contribution_recognition')
ax3.set_ylabel('count')
sns.countplot(data = df2, x = 'contribution_recognition', hue = 'likes_job')

# Management level
ax4 = fig2.add_subplot(624)
ax4.set_xlabel('well_managed')
ax4.set_ylabel('count')
sns.countplot(data = df2, x = 'well_managed', hue = 'likes_job')

# Work/life balance
ax5 = fig2.add_subplot(625)
ax5.set_xlabel('worklife_balance')
ax5.set_ylabel('count')
sns.countplot(data = df2, x = 'worklife_balance', hue = 'likes_job')

# Communication between departments
ax6 = fig2.add_subplot(626)
ax6.set_xlabel('effective_communication')
ax6.set_ylabel('count')
sns.countplot(data = df2, x = 'effective_communication', hue = 'likes_job')

# Supervisor rating
ax7 = fig2.add_subplot(627)
ax7.set_xlabel('respectful_supervisor')
ax7.set_ylabel('count')
sns.countplot(data = df2, x = 'respectful_supervisor', hue = 'likes_job')

# Relationship with peers
ax8 = fig2.add_subplot(628)
ax8.set_xlabel('good_relationship_with_coworkers')
ax8.set_ylabel('count')
sns.countplot(data = df2, x = 'good_relationship_with_coworkers', hue = 'likes_job')

# Company Ethics
ax9 = fig2.add_subplot(629)
ax9.set_xlabel('ethical_practices')
ax9.set_ylabel('count')
sns.countplot(data = df2, x = 'ethical_practices', hue = 'likes_job')

# How quick are conflicts resolved
ax10 = fig2.add_subplot(6,2,10)
ax10.set_xlabel('conflicts_immediately_resolved')
ax10.set_ylabel('count')
sns.countplot(data = df2, x = 'conflicts_immediately_resolved', hue = 'likes_job')

# Education Level
ax11 = fig2.add_subplot(6,2,11)
ax11.set_xlabel('education_level')
ax11.set_ylabel('count')
sns.countplot(data = df2, x = 'education_level', hue = 'likes_job')

# Salary
ax12 = fig2.add_subplot(6,2,12)
ax12.set_xlabel('salary_rate')
ax12.set_ylabel('count')
sns.countplot(data = df2, x = 'salary_rate', hue = 'likes_job')

# %%
df2['education_level'].value_counts()
# Out:
# 2    2528
# 1    1556
# Name: education_level, dtype: int64

# %%
df2['salary_rate'].value_counts()
# Out:
# 3    1434
# 2    1213
# 4     743
# 1     559
# 5     135
# Name: salary_rate, dtype: int64

# %%
df2.groupby('likes_job').mean()
# Out:
#            job_satisfaction_level  level_of_skill_used  expectations_clarity  \
# likes_job
# 0                        2.228284             3.634602              4.388370
# 1                        6.130435             5.997770              6.136009
#
#            contribution_recognition  career_development  well_managed  \
# likes_job
# 0                          2.663317            2.213209      2.692032
# 1                          5.156076            4.478632      4.861018
#
#            worklife_balance  effective_communication  respectful_supervisor  \
# likes_job
# 0                  3.863604                 2.789663               5.235463
# 1                  5.611669                 5.049052               6.284653
#
#            good_relationship_with_coworkers  ethical_practices  \
# likes_job
# 0                                  5.443647           5.016511
# 1                                  6.169082           6.093274
#
#            conflicts_immediately_resolved  education_level  salary_rate
# likes_job
# 0                                3.800431         1.686289     2.651831
# 1                                5.518395         1.584169     2.690450

# %%
# Features. Dropping target variables.

x = df2.drop(['likes_job','job_satisfaction_level'], axis=1)
x
# Out:
#       level_of_skill_used  expectations_clarity  contribution_recognition  \
# 0                       7                     7                         7
# 1                       7                     7                         7
# 2                       5                     5                         4
# 3                       1                     1                         1
# 4                       3                     1                         3
# ...                   ...                   ...                       ...
# 4079                    4                     4                         1
# 4080                    6                     7                         2
# 4081                    4                     4                         1
# 4082                    5                     5                         3
# 4083                    7                     7                         1
#
#       career_development  well_managed  worklife_balance  \
# 0                      5             2                 5
# 1                      7             7                 7
# 2                      4             1                 6
# 3                      1             1                 1
# 4                      1             2                 5
# ...                  ...           ...               ...
# 4079                   1             1                 1
# 4080                   5             6                 5
# 4081                   1             2                 3
# 4082                   3             6                 3
# 4083                   1             2                 1
#
#       effective_communication  respectful_supervisor  \
# 0                           6                      7
# 1                           7                      7
# 2                           1                      6
# 3                           1                      1
# 4                           1                      7
# ...                       ...                    ...
# 4079                        1                      4
# 4080                        6                      7
# 4081                        4                      4
# 4082                        3                      3
# 4083                        1                      5
#
#       good_relationship_with_coworkers  ethical_practices  \
# 0                                    7                  7
# 1                                    7                  7
# 2                                    4                  5
# 3                                    1                  6
# 4                                    7                  6
# ...                                ...                ...
# 4079                                 4                  3
# 4080                                 7                  6
# 4081                                 7                  6
# 4082                                 3                  5
# 4083                                 5                  7
#
#       conflicts_immediately_resolved  education_level  salary_rate
# 0                                  4                2            4
# 1                                  7                2            3
# 2                                  1                1            3
# 3                                  1                1            2
# 4                                  2                1            2
# ...                              ...              ...          ...
# 4079                               4                2            4
# 4080                               6                2            2
# 4081                               2                1            2
# 4082                               5                2            1
# 4083                               7                2            3
#
# [4084 rows x 13 columns]

# %%
# Multicollinearity quick check
x.corr()
# Out:
#                                   level_of_skill_used  expectations_clarity  \
# level_of_skill_used                          1.000000              0.559235
# expectations_clarity                         0.559235              1.000000
# contribution_recognition                     0.602459              0.504209
# career_development                           0.582643              0.451326
# well_managed                                 0.512888              0.481366
# worklife_balance                             0.384257              0.338756
# effective_communication                      0.508481              0.503434
# respectful_supervisor                        0.379405              0.344156
# good_relationship_with_coworkers             0.302235              0.261561
# ethical_practices                            0.415736              0.410757
# conflicts_immediately_resolved               0.453511              0.425057
# education_level                             -0.048319             -0.035048
# salary_rate                                  0.088491             -0.017058
#
#                                   contribution_recognition  \
# level_of_skill_used                               0.602459
# expectations_clarity                              0.504209
# contribution_recognition                          1.000000
# career_development                                0.698771
# well_managed                                      0.631940
# worklife_balance                                  0.516167
# effective_communication                           0.652432
# respectful_supervisor                             0.440224
# good_relationship_with_coworkers                  0.338992
# ethical_practices                                 0.451020
# conflicts_immediately_resolved                    0.540943
# education_level                                  -0.037957
# salary_rate                                       0.056214
#
#                                   career_development  well_managed  \
# level_of_skill_used                         0.582643      0.512888
# expectations_clarity                        0.451326      0.481366
# contribution_recognition                    0.698771      0.631940
# career_development                          1.000000      0.609257
# well_managed                                0.609257      1.000000
# worklife_balance                            0.425575      0.492068
# effective_communication                     0.572997      0.649121
# respectful_supervisor                       0.351345      0.369086
# good_relationship_with_coworkers            0.300468      0.307182
# ethical_practices                           0.407488      0.519890
# conflicts_immediately_resolved              0.497393      0.596498
# education_level                            -0.060798     -0.059992
# salary_rate                                 0.054183     -0.008584
#
#                                   worklife_balance  effective_communication  \
# level_of_skill_used                       0.384257                 0.508481
# expectations_clarity                      0.338756                 0.503434
# contribution_recognition                  0.516167                 0.652432
# career_development                        0.425575                 0.572997
# well_managed                              0.492068                 0.649121
# worklife_balance                          1.000000                 0.487506
# effective_communication                   0.487506                 1.000000
# respectful_supervisor                     0.389899                 0.471082
# good_relationship_with_coworkers          0.294164                 0.358373
# ethical_practices                         0.350381                 0.489228
# conflicts_immediately_resolved            0.431643                 0.589690
# education_level                          -0.033523                -0.041553
# salary_rate                               0.036455                 0.044992
#
#                                   respectful_supervisor  \
# level_of_skill_used                            0.379405
# expectations_clarity                           0.344156
# contribution_recognition                       0.440224
# career_development                             0.351345
# well_managed                                   0.369086
# worklife_balance                               0.389899
# effective_communication                        0.471082
# respectful_supervisor                          1.000000
# good_relationship_with_coworkers               0.597125
# ethical_practices                              0.446082
# conflicts_immediately_resolved                 0.454056
# education_level                               -0.005886
# salary_rate                                    0.077747
#
#                                   good_relationship_with_coworkers  \
# level_of_skill_used                                       0.302235
# expectations_clarity                                      0.261561
# contribution_recognition                                  0.338992
# career_development                                        0.300468
# well_managed                                              0.307182
# worklife_balance                                          0.294164
# effective_communication                                   0.358373
# respectful_supervisor                                     0.597125
# good_relationship_with_coworkers                          1.000000
# ethical_practices                                         0.455408
# conflicts_immediately_resolved                            0.408546
# education_level                                           0.016328
# salary_rate                                               0.093796
#
#                                   ethical_practices  \
# level_of_skill_used                        0.415736
# expectations_clarity                       0.410757
# contribution_recognition                   0.451020
# career_development                         0.407488
# well_managed                               0.519890
# worklife_balance                           0.350381
# effective_communication                    0.489228
# respectful_supervisor                      0.446082
# good_relationship_with_coworkers           0.455408
# ethical_practices                          1.000000
# conflicts_immediately_resolved             0.637306
# education_level                           -0.037810
# salary_rate                                0.032769
#
#                                   conflicts_immediately_resolved  \
# level_of_skill_used                                     0.453511
# expectations_clarity                                    0.425057
# contribution_recognition                                0.540943
# career_development                                      0.497393
# well_managed                                            0.596498
# worklife_balance                                        0.431643
# effective_communication                                 0.589690
# respectful_supervisor                                   0.454056
# good_relationship_with_coworkers                        0.408546
# ethical_practices                                       0.637306
# conflicts_immediately_resolved                          1.000000
# education_level                                        -0.032349
# salary_rate                                             0.069175
#
#                                   education_level  salary_rate
# level_of_skill_used                     -0.048319     0.088491
# expectations_clarity                    -0.035048    -0.017058
# contribution_recognition                -0.037957     0.056214
# career_development                      -0.060798     0.054183
# well_managed                            -0.059992    -0.008584
# worklife_balance                        -0.033523     0.036455
# effective_communication                 -0.041553     0.044992
# respectful_supervisor                   -0.005886     0.077747
# good_relationship_with_coworkers         0.016328     0.093796
# ethical_practices                       -0.037810     0.032769
# conflicts_immediately_resolved          -0.032349     0.069175
# education_level                          1.000000     0.366699
# salary_rate                              0.366699     1.000000

# %%
# Class variable

y = df2['likes_job']

# %%
# Machine Learning Imports. Logistic Regression

from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# For evaluation later
from sklearn import metrics

# %%
# Creating Logistic Regression Model. Not training model yet. For accuracy comparison.

log = LogisticRegression()

# Fitting data
log.fit(x,y)

# Accuracy check
log.score(x,y)
# Out:
# 0.8398628795298727

# %%
# Flattened array of feature coefficients
np.ravel(log.coef_)
# Out:
# array([ 0.46467312,  0.20993822,  0.20522782,  0.10015839,  0.12333352,
#         0.20716066,  0.13707483,  0.00126985, -0.00969092, -0.14629446,
#         0.04739188, -0.54338647,  0.01891729])

# %%
# Coefficients from the model

coeff_df2 = pd.DataFrame(x.columns, columns = ['Features'])
coeff_df2['Coefficients'] = np.ravel(log.coef_)

# %%
coeff_df2
# Out:
#                             Features  Coefficients
# 0                level_of_skill_used      0.464673
# 1               expectations_clarity      0.209938
# 2           contribution_recognition      0.205228
# 3                 career_development      0.100158
# 4                       well_managed      0.123334
# 5                   worklife_balance      0.207161
# 6            effective_communication      0.137075
# 7              respectful_supervisor      0.001270
# 8   good_relationship_with_coworkers     -0.009691
# 9                  ethical_practices     -0.146294
# 10    conflicts_immediately_resolved      0.047392
# 11                   education_level     -0.543386
# 12                       salary_rate      0.018917

# %% [markdown]
# ## Logistic Regression - Training and Testing Data Set

# %%
# Splitting the data. Test size set to 33% and arbitrary random_state = 100

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.33, random_state = 100)

# %%
# Creating Logistic Regression model
log2 = LogisticRegression()

# Fitting new model
log2.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
# Predict the classes of the testing data set. Employee likes job or not.
y_predict = log2.predict(X_test)

# Accuracy score
metrics.accuracy_score(y_test, y_predict)
# Out:
# 0.8456973293768546

# %%
# Classification report
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test, y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.73      0.77       469
#            1       0.86      0.91      0.88       879
#
#     accuracy                           0.85      1348
#    macro avg       0.84      0.82      0.83      1348
# weighted avg       0.84      0.85      0.84      1348

# %%
# Confusion matrix

pd.crosstab(y_test,y_predict,rownames=['Actual'],colnames=['Predicted'],margins=True)
# Out:
# Predicted    0    1   All
# Actual
# 0          341  128   469
# 1           80  799   879
# All        421  927  1348

# %%
# Improved confusion matrix

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_predict)
plt.figure(figsize = (10,7))
sns.heatmap(cm, annot = True, cmap="YlGnBu")
plt.xlabel('Predicted')
plt.ylabel('Actual')
# Out:
# Text(70.0, 0.5, 'Actual')

# %% [markdown]
# ## Decision Tree

# %%
# Decision tree imports
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn.model_selection import train_test_split

# %%
# Train test split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=100)

# %%
# Decision tree model
c = DecisionTreeClassifier(min_samples_split=101)

# %%
# Fit model
c.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(min_samples_split=101)

# %%
# Predict classes
y_pred = c.predict(X_test)

# %%
# Accuracy score
metrics.accuracy_score(y_test, y_pred)
# Out:
# 0.836053412462908

# %%
# Classification report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.73      0.76       469
#            1       0.86      0.89      0.88       879
#
#     accuracy                           0.84      1348
#    macro avg       0.82      0.81      0.82      1348
# weighted avg       0.83      0.84      0.83      1348

# %%
# Confusion matrix

pd.crosstab(y_test,y_pred,rownames=['Actual'],colnames=['Predicted'],margins=True)
# Out:
# Predicted    0    1   All
# Actual
# 0          341  128   469
# 1           93  786   879
# All        434  914  1348

# %%
# Confusion matrix

cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize = (10,7))
sns.heatmap(cm, annot = True, cmap="YlGnBu")
plt.xlabel('Predicted')
plt.ylabel('Actual')
# Out:
# Text(70.0, 0.5, 'Actual')

# %% [markdown]
# ## Naive Bayes

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.33, random_state = 100)

# %%
# Naive Bayes model

from sklearn.naive_bayes import MultinomialNB

naive_bayes = MultinomialNB()
naive_bayes.fit(X_train, y_train)
# Out:
# MultinomialNB()

# %%
# Predict testing set
predictions = naive_bayes.predict(X_test)

# %%
# Accuracy score
metrics.accuracy_score(y_test, predictions)
# Out:
# 0.7945103857566765

# %%
naive_bayes.predict([[5,4,6.5,7,3,4,2,1,4,5,6,5,4]])
# Out:
# array([1], dtype=int64)

# %%
# Classification report
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.65      0.69       469
#            1       0.82      0.87      0.85       879
#
#     accuracy                           0.79      1348
#    macro avg       0.78      0.76      0.77      1348
# weighted avg       0.79      0.79      0.79      1348

# %%
# Confusion matrix

pd.crosstab(y_test,predictions,rownames=['Actual'],colnames=['Predicted'],margins=True)
# Out:
# Predicted    0    1   All
# Actual
# 0          304  165   469
# 1          112  767   879
# All        416  932  1348

# %%
# Confusion matrix

cm = confusion_matrix(y_test, predictions)
plt.figure(figsize = (10,7))
sns.heatmap(cm, annot = True, cmap="YlGnBu")
plt.xlabel('Predicted')
plt.ylabel('Actual')
# Out:
# Text(70.0, 0.5, 'Actual')

# %%
# ROC Curves of all three models. AUC scores beside them.

y_pred_proba = log2.predict_proba(X_test)[::,1]
fpr, tpr, _ = metrics.roc_curve(y_test, y_pred_proba)
auc = metrics.roc_auc_score(y_test, y_pred_proba)
plt.plot(fpr,tpr,label="Logistic Regression, auc="+str(auc))

y_pred_proba2 = c.predict_proba(X_test)[::,1]
fpr2, tpr2, _ = metrics.roc_curve(y_test, y_pred_proba2)
auc2 = metrics.roc_auc_score(y_test, y_pred_proba2)
plt.plot(fpr2,tpr2,label="Decision Tree, auc="+str(auc2))

y_pred_proba3 = naive_bayes.predict_proba(X_test)[::,1]
fpr3, tpr3, _ = metrics.roc_curve(y_test, y_pred_proba3)
auc3 = metrics.roc_auc_score(y_test, y_pred_proba3)
plt.plot(fpr3,tpr3,label="Naive Bayes, auc="+str(auc3))

plt.legend(loc=4)
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.title('ROC Curves')
plt.show()

# %% [markdown]
# ## Unsupervised Learning - Apriori algorithm

# %%
# Apriori imports

import csv
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

# %%
# Removing class variables. Only comparing features.
df_a = df2.drop(['job_satisfaction_level','likes_job'],axis=1)

# %%
df_a
# Out:
#       level_of_skill_used  expectations_clarity  contribution_recognition  \
# 0                       7                     7                         7
# 1                       7                     7                         7
# 2                       5                     5                         4
# 3                       1                     1                         1
# 4                       3                     1                         3
# ...                   ...                   ...                       ...
# 4079                    4                     4                         1
# 4080                    6                     7                         2
# 4081                    4                     4                         1
# 4082                    5                     5                         3
# 4083                    7                     7                         1
#
#       career_development  well_managed  worklife_balance  \
# 0                      5             2                 5
# 1                      7             7                 7
# 2                      4             1                 6
# 3                      1             1                 1
# 4                      1             2                 5
# ...                  ...           ...               ...
# 4079                   1             1                 1
# 4080                   5             6                 5
# 4081                   1             2                 3
# 4082                   3             6                 3
# 4083                   1             2                 1
#
#       effective_communication  respectful_supervisor  \
# 0                           6                      7
# 1                           7                      7
# 2                           1                      6
# 3                           1                      1
# 4                           1                      7
# ...                       ...                    ...
# 4079                        1                      4
# 4080                        6                      7
# 4081                        4                      4
# 4082                        3                      3
# 4083                        1                      5
#
#       good_relationship_with_coworkers  ethical_practices  \
# 0                                    7                  7
# 1                                    7                  7
# 2                                    4                  5
# 3                                    1                  6
# 4                                    7                  6
# ...                                ...                ...
# 4079                                 4                  3
# 4080                                 7                  6
# 4081                                 7                  6
# 4082                                 3                  5
# 4083                                 5                  7
#
#       conflicts_immediately_resolved  education_level  salary_rate
# 0                                  4                2            4
# 1                                  7                2            3
# 2                                  1                1            3
# 3                                  1                1            2
# 4                                  2                1            2
# ...                              ...              ...          ...
# 4079                               4                2            4
# 4080                               6                2            2
# 4081                               2                1            2
# 4082                               5                2            1
# 4083                               7                2            3
#
# [4084 rows x 13 columns]

# %%
# Transforming rating (numerical variables) into categorical (strongly disagree to strongly agree)

df_a = df_a[['level_of_skill_used', 'expectations_clarity','contribution_recognition', 
          'career_development', 'well_managed','worklife_balance', 'effective_communication', 'respectful_supervisor',
          'good_relationship_with_coworkers', 'ethical_practices',
           'conflicts_immediately_resolved']].replace({1:'Strongly disagree',2:'Moderately disagree',3:'Mildly disagree',4:'Neither agree nor disagree',5:'Mildly agree',6:'Moderately agree',7:'Strongly agree'})

df_a
# Out:
#              level_of_skill_used        expectations_clarity  \
# 0                 Strongly agree              Strongly agree
# 1                 Strongly agree              Strongly agree
# 2                   Mildly agree                Mildly agree
# 3              Strongly disagree           Strongly disagree
# 4                Mildly disagree           Strongly disagree
# ...                          ...                         ...
# 4079  Neither agree nor disagree  Neither agree nor disagree
# 4080            Moderately agree              Strongly agree
# 4081  Neither agree nor disagree  Neither agree nor disagree
# 4082                Mildly agree                Mildly agree
# 4083              Strongly agree              Strongly agree
#
#         contribution_recognition          career_development  \
# 0                 Strongly agree                Mildly agree
# 1                 Strongly agree              Strongly agree
# 2     Neither agree nor disagree  Neither agree nor disagree
# 3              Strongly disagree           Strongly disagree
# 4                Mildly disagree           Strongly disagree
# ...                          ...                         ...
# 4079           Strongly disagree           Strongly disagree
# 4080         Moderately disagree                Mildly agree
# 4081           Strongly disagree           Strongly disagree
# 4082             Mildly disagree             Mildly disagree
# 4083           Strongly disagree           Strongly disagree
#
#              well_managed   worklife_balance     effective_communication  \
# 0     Moderately disagree       Mildly agree            Moderately agree
# 1          Strongly agree     Strongly agree              Strongly agree
# 2       Strongly disagree   Moderately agree           Strongly disagree
# 3       Strongly disagree  Strongly disagree           Strongly disagree
# 4     Moderately disagree       Mildly agree           Strongly disagree
# ...                   ...                ...                         ...
# 4079    Strongly disagree  Strongly disagree           Strongly disagree
# 4080     Moderately agree       Mildly agree            Moderately agree
# 4081  Moderately disagree    Mildly disagree  Neither agree nor disagree
# 4082     Moderately agree    Mildly disagree             Mildly disagree
# 4083  Moderately disagree  Strongly disagree           Strongly disagree
#
#            respectful_supervisor good_relationship_with_coworkers  \
# 0                 Strongly agree                   Strongly agree
# 1                 Strongly agree                   Strongly agree
# 2               Moderately agree       Neither agree nor disagree
# 3              Strongly disagree                Strongly disagree
# 4                 Strongly agree                   Strongly agree
# ...                          ...                              ...
# 4079  Neither agree nor disagree       Neither agree nor disagree
# 4080              Strongly agree                   Strongly agree
# 4081  Neither agree nor disagree                   Strongly agree
# 4082             Mildly disagree                  Mildly disagree
# 4083                Mildly agree                     Mildly agree
#
#      ethical_practices conflicts_immediately_resolved
# 0       Strongly agree     Neither agree nor disagree
# 1       Strongly agree                 Strongly agree
# 2         Mildly agree              Strongly disagree
# 3     Moderately agree              Strongly disagree
# 4     Moderately agree            Moderately disagree
# ...                ...                            ...
# 4079   Mildly disagree     Neither agree nor disagree
# 4080  Moderately agree               Moderately agree
# 4081  Moderately agree            Moderately disagree
# 4082      Mildly agree                   Mildly agree
# 4083    Strongly agree                 Strongly agree
#
# [4084 rows x 11 columns]

# %%
# Converting data to make it appropriate for Apriori
df_a['level_of_skill_used'] = df_a['level_of_skill_used'].map('level_of_skill_used = {}'.format)
df_a['expectations_clarity'] = df_a['expectations_clarity'].map('expectations_clarity = {}'.format)
df_a['contribution_recognition'] = df_a['contribution_recognition'].map('contribution_recognition = {}'.format)
df_a['career_development'] = df_a['career_development'].map('career_development = {}'.format)
df_a['well_managed'] = df_a['well_managed'].map('well_managed = {}'.format)
df_a['worklife_balance'] = df_a['worklife_balance'].map('worklife_balance = {}'.format)
df_a['effective_communication'] = df_a['effective_communication'].map('effective_communication = {}'.format)
df_a['respectful_supervisor'] = df_a['respectful_supervisor'].map('respectful_supervisor = {}'.format)
df_a['good_relationship_with_coworkers'] = df_a['good_relationship_with_coworkers'].map('good_relationship_with_coworkers = {}'.format)
df_a['ethical_practices'] = df_a['ethical_practices'].map('ethical_practices = {}'.format)
df_a['conflicts_immediately_resolved'] = df_a['conflicts_immediately_resolved'].map('conflicts_immediately_resolved = {}'.format)

df_a
# Out:
#                                    level_of_skill_used  \
# 0                 level_of_skill_used = Strongly agree
# 1                 level_of_skill_used = Strongly agree
# 2                   level_of_skill_used = Mildly agree
# 3              level_of_skill_used = Strongly disagree
# 4                level_of_skill_used = Mildly disagree
# ...                                                ...
# 4079  level_of_skill_used = Neither agree nor disagree
# 4080            level_of_skill_used = Moderately agree
# 4081  level_of_skill_used = Neither agree nor disagree
# 4082                level_of_skill_used = Mildly agree
# 4083              level_of_skill_used = Strongly agree
#
#                                    expectations_clarity  \
# 0                 expectations_clarity = Strongly agree
# 1                 expectations_clarity = Strongly agree
# 2                   expectations_clarity = Mildly agree
# 3              expectations_clarity = Strongly disagree
# 4              expectations_clarity = Strongly disagree
# ...                                                 ...
# 4079  expectations_clarity = Neither agree nor disagree
# 4080              expectations_clarity = Strongly agree
# 4081  expectations_clarity = Neither agree nor disagree
# 4082                expectations_clarity = Mildly agree
# 4083              expectations_clarity = Strongly agree
#
#                                contribution_recognition  \
# 0             contribution_recognition = Strongly agree
# 1             contribution_recognition = Strongly agree
# 2     contribution_recognition = Neither agree nor d...
# 3          contribution_recognition = Strongly disagree
# 4            contribution_recognition = Mildly disagree
# ...                                                 ...
# 4079       contribution_recognition = Strongly disagree
# 4080     contribution_recognition = Moderately disagree
# 4081       contribution_recognition = Strongly disagree
# 4082         contribution_recognition = Mildly disagree
# 4083       contribution_recognition = Strongly disagree
#
#                                    career_development  \
# 0                   career_development = Mildly agree
# 1                 career_development = Strongly agree
# 2     career_development = Neither agree nor disagree
# 3              career_development = Strongly disagree
# 4              career_development = Strongly disagree
# ...                                               ...
# 4079           career_development = Strongly disagree
# 4080                career_development = Mildly agree
# 4081           career_development = Strongly disagree
# 4082             career_development = Mildly disagree
# 4083           career_development = Strongly disagree
#
#                             well_managed  \
# 0     well_managed = Moderately disagree
# 1          well_managed = Strongly agree
# 2       well_managed = Strongly disagree
# 3       well_managed = Strongly disagree
# 4     well_managed = Moderately disagree
# ...                                  ...
# 4079    well_managed = Strongly disagree
# 4080     well_managed = Moderately agree
# 4081  well_managed = Moderately disagree
# 4082     well_managed = Moderately agree
# 4083  well_managed = Moderately disagree
#
#                           worklife_balance  \
# 0          worklife_balance = Mildly agree
# 1        worklife_balance = Strongly agree
# 2      worklife_balance = Moderately agree
# 3     worklife_balance = Strongly disagree
# 4          worklife_balance = Mildly agree
# ...                                    ...
# 4079  worklife_balance = Strongly disagree
# 4080       worklife_balance = Mildly agree
# 4081    worklife_balance = Mildly disagree
# 4082    worklife_balance = Mildly disagree
# 4083  worklife_balance = Strongly disagree
#
#                                 effective_communication  \
# 0            effective_communication = Moderately agree
# 1              effective_communication = Strongly agree
# 2           effective_communication = Strongly disagree
# 3           effective_communication = Strongly disagree
# 4           effective_communication = Strongly disagree
# ...                                                 ...
# 4079        effective_communication = Strongly disagree
# 4080         effective_communication = Moderately agree
# 4081  effective_communication = Neither agree nor di...
# 4082          effective_communication = Mildly disagree
# 4083        effective_communication = Strongly disagree
#
#                                   respectful_supervisor  \
# 0                respectful_supervisor = Strongly agree
# 1                respectful_supervisor = Strongly agree
# 2              respectful_supervisor = Moderately agree
# 3             respectful_supervisor = Strongly disagree
# 4                respectful_supervisor = Strongly agree
# ...                                                 ...
# 4079  respectful_supervisor = Neither agree nor disa...
# 4080             respectful_supervisor = Strongly agree
# 4081  respectful_supervisor = Neither agree nor disa...
# 4082            respectful_supervisor = Mildly disagree
# 4083               respectful_supervisor = Mildly agree
#
#                        good_relationship_with_coworkers  \
# 0     good_relationship_with_coworkers = Strongly agree
# 1     good_relationship_with_coworkers = Strongly agree
# 2     good_relationship_with_coworkers = Neither agr...
# 3     good_relationship_with_coworkers = Strongly di...
# 4     good_relationship_with_coworkers = Strongly agree
# ...                                                 ...
# 4079  good_relationship_with_coworkers = Neither agr...
# 4080  good_relationship_with_coworkers = Strongly agree
# 4081  good_relationship_with_coworkers = Strongly agree
# 4082  good_relationship_with_coworkers = Mildly disa...
# 4083    good_relationship_with_coworkers = Mildly agree
#
#                          ethical_practices  \
# 0       ethical_practices = Strongly agree
# 1       ethical_practices = Strongly agree
# 2         ethical_practices = Mildly agree
# 3     ethical_practices = Moderately agree
# 4     ethical_practices = Moderately agree
# ...                                    ...
# 4079   ethical_practices = Mildly disagree
# 4080  ethical_practices = Moderately agree
# 4081  ethical_practices = Moderately agree
# 4082      ethical_practices = Mildly agree
# 4083    ethical_practices = Strongly agree
#
#                          conflicts_immediately_resolved
# 0     conflicts_immediately_resolved = Neither agree...
# 1       conflicts_immediately_resolved = Strongly agree
# 2     conflicts_immediately_resolved = Strongly disa...
# 3     conflicts_immediately_resolved = Strongly disa...
# 4     conflicts_immediately_resolved = Moderately di...
# ...                                                 ...
# 4079  conflicts_immediately_resolved = Neither agree...
# 4080  conflicts_immediately_resolved = Moderately agree
# 4081  conflicts_immediately_resolved = Moderately di...
# 4082      conflicts_immediately_resolved = Mildly agree
# 4083    conflicts_immediately_resolved = Strongly agree
#
# [4084 rows x 11 columns]

# %%
# Adding education_level. It only ranges from 1-2 unlike other features. Replaced numbers to actual meaning for Apriori.

df_a['education_level'] = df2[['education_level']].replace({1:'Education = Primary/secondary school or technical/trade certificate or diploma',2:'Education = University qualification'})

# %%
# Adding back salary_rate. Five available numbers. Replaced numbers to actual salary ranges.

df_a['salary_rate'] = df2[['salary_rate']].replace([1,2,3,4,5],['Salary = Less than $60,000','Salary = $ 60,000-70,000','Salary = $ 80,000-109,999','Salary = $ 110,000-159,999','Salary = $ 160,000 and over'])

# %%
df_a
# Out:
#                                    level_of_skill_used  \
# 0                 level_of_skill_used = Strongly agree
# 1                 level_of_skill_used = Strongly agree
# 2                   level_of_skill_used = Mildly agree
# 3              level_of_skill_used = Strongly disagree
# 4                level_of_skill_used = Mildly disagree
# ...                                                ...
# 4079  level_of_skill_used = Neither agree nor disagree
# 4080            level_of_skill_used = Moderately agree
# 4081  level_of_skill_used = Neither agree nor disagree
# 4082                level_of_skill_used = Mildly agree
# 4083              level_of_skill_used = Strongly agree
#
#                                    expectations_clarity  \
# 0                 expectations_clarity = Strongly agree
# 1                 expectations_clarity = Strongly agree
# 2                   expectations_clarity = Mildly agree
# 3              expectations_clarity = Strongly disagree
# 4              expectations_clarity = Strongly disagree
# ...                                                 ...
# 4079  expectations_clarity = Neither agree nor disagree
# 4080              expectations_clarity = Strongly agree
# 4081  expectations_clarity = Neither agree nor disagree
# 4082                expectations_clarity = Mildly agree
# 4083              expectations_clarity = Strongly agree
#
#                                contribution_recognition  \
# 0             contribution_recognition = Strongly agree
# 1             contribution_recognition = Strongly agree
# 2     contribution_recognition = Neither agree nor d...
# 3          contribution_recognition = Strongly disagree
# 4            contribution_recognition = Mildly disagree
# ...                                                 ...
# 4079       contribution_recognition = Strongly disagree
# 4080     contribution_recognition = Moderately disagree
# 4081       contribution_recognition = Strongly disagree
# 4082         contribution_recognition = Mildly disagree
# 4083       contribution_recognition = Strongly disagree
#
#                                    career_development  \
# 0                   career_development = Mildly agree
# 1                 career_development = Strongly agree
# 2     career_development = Neither agree nor disagree
# 3              career_development = Strongly disagree
# 4              career_development = Strongly disagree
# ...                                               ...
# 4079           career_development = Strongly disagree
# 4080                career_development = Mildly agree
# 4081           career_development = Strongly disagree
# 4082             career_development = Mildly disagree
# 4083           career_development = Strongly disagree
#
#                             well_managed  \
# 0     well_managed = Moderately disagree
# 1          well_managed = Strongly agree
# 2       well_managed = Strongly disagree
# 3       well_managed = Strongly disagree
# 4     well_managed = Moderately disagree
# ...                                  ...
# 4079    well_managed = Strongly disagree
# 4080     well_managed = Moderately agree
# 4081  well_managed = Moderately disagree
# 4082     well_managed = Moderately agree
# 4083  well_managed = Moderately disagree
#
#                           worklife_balance  \
# 0          worklife_balance = Mildly agree
# 1        worklife_balance = Strongly agree
# 2      worklife_balance = Moderately agree
# 3     worklife_balance = Strongly disagree
# 4          worklife_balance = Mildly agree
# ...                                    ...
# 4079  worklife_balance = Strongly disagree
# 4080       worklife_balance = Mildly agree
# 4081    worklife_balance = Mildly disagree
# 4082    worklife_balance = Mildly disagree
# 4083  worklife_balance = Strongly disagree
#
#                                 effective_communication  \
# 0            effective_communication = Moderately agree
# 1              effective_communication = Strongly agree
# 2           effective_communication = Strongly disagree
# 3           effective_communication = Strongly disagree
# 4           effective_communication = Strongly disagree
# ...                                                 ...
# 4079        effective_communication = Strongly disagree
# 4080         effective_communication = Moderately agree
# 4081  effective_communication = Neither agree nor di...
# 4082          effective_communication = Mildly disagree
# 4083        effective_communication = Strongly disagree
#
#                                   respectful_supervisor  \
# 0                respectful_supervisor = Strongly agree
# 1                respectful_supervisor = Strongly agree
# 2              respectful_supervisor = Moderately agree
# 3             respectful_supervisor = Strongly disagree
# 4                respectful_supervisor = Strongly agree
# ...                                                 ...
# 4079  respectful_supervisor = Neither agree nor disa...
# 4080             respectful_supervisor = Strongly agree
# 4081  respectful_supervisor = Neither agree nor disa...
# 4082            respectful_supervisor = Mildly disagree
# 4083               respectful_supervisor = Mildly agree
#
#                        good_relationship_with_coworkers  \
# 0     good_relationship_with_coworkers = Strongly agree
# 1     good_relationship_with_coworkers = Strongly agree
# 2     good_relationship_with_coworkers = Neither agr...
# 3     good_relationship_with_coworkers = Strongly di...
# 4     good_relationship_with_coworkers = Strongly agree
# ...                                                 ...
# 4079  good_relationship_with_coworkers = Neither agr...
# 4080  good_relationship_with_coworkers = Strongly agree
# 4081  good_relationship_with_coworkers = Strongly agree
# 4082  good_relationship_with_coworkers = Mildly disa...
# 4083    good_relationship_with_coworkers = Mildly agree
#
#                          ethical_practices  \
# 0       ethical_practices = Strongly agree
# 1       ethical_practices = Strongly agree
# 2         ethical_practices = Mildly agree
# 3     ethical_practices = Moderately agree
# 4     ethical_practices = Moderately agree
# ...                                    ...
# 4079   ethical_practices = Mildly disagree
# 4080  ethical_practices = Moderately agree
# 4081  ethical_practices = Moderately agree
# 4082      ethical_practices = Mildly agree
# 4083    ethical_practices = Strongly agree
#
#                          conflicts_immediately_resolved  \
# 0     conflicts_immediately_resolved = Neither agree...
# 1       conflicts_immediately_resolved = Strongly agree
# 2     conflicts_immediately_resolved = Strongly disa...
# 3     conflicts_immediately_resolved = Strongly disa...
# 4     conflicts_immediately_resolved = Moderately di...
# ...                                                 ...
# 4079  conflicts_immediately_resolved = Neither agree...
# 4080  conflicts_immediately_resolved = Moderately agree
# 4081  conflicts_immediately_resolved = Moderately di...
# 4082      conflicts_immediately_resolved = Mildly agree
# 4083    conflicts_immediately_resolved = Strongly agree
#
#                                         education_level  \
# 0                  Education = University qualification
# 1                  Education = University qualification
# 2     Education = Primary/secondary school or techni...
# 3     Education = Primary/secondary school or techni...
# 4     Education = Primary/secondary school or techni...
# ...                                                 ...
# 4079               Education = University qualification
# 4080               Education = University qualification
# 4081  Education = Primary/secondary school or techni...
# 4082               Education = University qualification
# 4083               Education = University qualification
#
#                      salary_rate
# 0     Salary = $ 110,000-159,999
# 1      Salary = $ 80,000-109,999
# 2      Salary = $ 80,000-109,999
# 3       Salary = $ 60,000-70,000
# 4       Salary = $ 60,000-70,000
# ...                          ...
# 4079  Salary = $ 110,000-159,999
# 4080    Salary = $ 60,000-70,000
# 4081    Salary = $ 60,000-70,000
# 4082  Salary = Less than $60,000
# 4083   Salary = $ 80,000-109,999
#
# [4084 rows x 13 columns]

# %%
df_a.to_numpy()
# Out:
# array([['level_of_skill_used = Strongly agree',
#         'expectations_clarity = Strongly agree',
#         'contribution_recognition = Strongly agree', ...,
#         'conflicts_immediately_resolved = Neither agree nor disagree',
#         'Education = University qualification',
#         'Salary = $ 110,000-159,999'],
#        ['level_of_skill_used = Strongly agree',
#         'expectations_clarity = Strongly agree',
#         'contribution_recognition = Strongly agree', ...,
#         'conflicts_immediately_resolved = Strongly agree',
#         'Education = University qualification',
#         'Salary = $ 80,000-109,999'],
#        ['level_of_skill_used = Mildly agree',
#         'expectations_clarity = Mildly agree',
#         'contribution_recognition = Neither agree nor disagree', ...,
#         'conflicts_immediately_resolved = Strongly disagree',
#         'Education = Primary/secondary school or technical/trade certificate or diploma',
#         'Salary = $ 80,000-109,999'],
#        ...,
#        ['level_of_skill_used = Neither agree nor disagree',
#         'expectations_clarity = Neither agree nor disagree',
#         'contribution_recognition = Strongly disagree', ...,
#         'conflicts_immediately_resolved = Moderately disagree',
#         'Education = Primary/secondary school or technical/trade certificate or diploma',
#         'Salary = $ 60,000-70,000'],
#        ['level_of_skill_used = Mildly agree',
#         'expectations_clarity = Mildly agree',
#         'contribution_recognition = Mildly disagree', ...,
#         'conflicts_immediately_resolved = Mildly agree',
#         'Education = University qualification',
#         'Salary = Less than $60,000'],
#        ['level_of_skill_used = Strongly agree',
#         'expectations_clarity = Strongly agree',
#         'contribution_recognition = Strongly disagree', ...,
#         'conflicts_immediately_resolved = Strongly agree',
#         'Education = University qualification',
#         'Salary = $ 80,000-109,999']], dtype=object)

# %%
# Transform data for the apriori algorithm
te = TransactionEncoder()
te_array = te.fit(df_a.to_numpy()).transform(df_a.to_numpy())

# %%
te_array
# Out:
# array([[False,  True,  True, ..., False, False, False],
#        [False,  True, False, ..., False,  True, False],
#        [ True, False, False, ..., False, False, False],
#        ...,
#        [ True, False, False, ..., False, False, False],
#        [False,  True, False, ..., False, False, False],
#        [False,  True, False, ..., False, False,  True]])

# %%
te.columns_
# Out:
# ['Education = Primary/secondary school or technical/trade certificate or diploma',
#  'Education = University qualification',
#  'Salary = $ 110,000-159,999',
#  'Salary = $ 160,000 and over',
#  'Salary = $ 60,000-70,000',
#  'Salary = $ 80,000-109,999',
#  'Salary = Less than $60,000',
#  'career_development = Mildly agree',
#  'career_development = Mildly disagree',
#  'career_development = Moderately agree',
#  'career_development = Moderately disagree',
#  'career_development = Neither agree nor disagree',
#  'career_development = Strongly agree',
#  'career_development = Strongly disagree',
#  'conflicts_immediately_resolved = Mildly agree',
#  'conflicts_immediately_resolved = Mildly disagree',
#  'conflicts_immediately_resolved = Moderately agree',
#  'conflicts_immediately_resolved = Moderately disagree',
#  'conflicts_immediately_resolved = Neither agree nor disagree',
#  'conflicts_immediately_resolved = Strongly agree',
#  'conflicts_immediately_resolved = Strongly disagree',
#  'contribution_recognition = Mildly agree',
#  'contribution_recognition = Mildly disagree',
#  'contribution_recognition = Moderately agree',
#  'contribution_recognition = Moderately disagree',
#  'contribution_recognition = Neither agree nor disagree',
#  'contribution_recognition = Strongly agree',
#  'contribution_recognition = Strongly disagree',
#  'effective_communication = Mildly agree',
#  'effective_communication = Mildly disagree',
#  'effective_communication = Moderately agree',
#  'effective_communication = Moderately disagree',
#  'effective_communication = Neither agree nor disagree',
#  'effective_communication = Strongly agree',
#  'effective_communication = Strongly disagree',
#  'ethical_practices = Mildly agree',
#  'ethical_practices = Mildly disagree',
#  'ethical_practices = Moderately agree',
#  'ethical_practices = Moderately disagree',
#  'ethical_practices = Neither agree nor disagree',
#  'ethical_practices = Strongly agree',
#  'ethical_practices = Strongly disagree',
#  'expectations_clarity = Mildly agree',
#  'expectations_clarity = Mildly disagree',
#  'expectations_clarity = Moderately agree',
#  'expectations_clarity = Moderately disagree',
#  'expectations_clarity = Neither agree nor disagree',
#  'expectations_clarity = Strongly agree',
#  'expectations_clarity = Strongly disagree',
#  'good_relationship_with_coworkers = Mildly agree',
#  'good_relationship_with_coworkers = Mildly disagree',
#  'good_relationship_with_coworkers = Moderately agree',
#  'good_relationship_with_coworkers = Moderately disagree',
#  'good_relationship_with_coworkers = Neither agree nor disagree',
#  'good_relationship_with_coworkers = Strongly agree',
#  'good_relationship_with_coworkers = Strongly disagree',
#  'level_of_skill_used = Mildly agree',
#  'level_of_skill_used = Mildly disagree',
#  'level_of_skill_used = Moderately agree',
#  'level_of_skill_used = Moderately disagree',
#  'level_of_skill_used = Neither agree nor disagree',
#  'level_of_skill_used = Strongly agree',
#  'level_of_skill_used = Strongly disagree',
#  'respectful_supervisor = Mildly agree',
#  'respectful_supervisor = Mildly disagree',
#  'respectful_supervisor = Moderately agree',
#  'respectful_supervisor = Moderately disagree',
#  'respectful_supervisor = Neither agree nor disagree',
#  'respectful_supervisor = Strongly agree',
#  'respectful_supervisor = Strongly disagree',
#  'well_managed = Mildly agree',
#  'well_managed = Mildly disagree',
#  'well_managed = Moderately agree',
#  'well_managed = Moderately disagree',
#  'well_managed = Neither agree nor disagree',
#  'well_managed = Strongly agree',
#  'well_managed = Strongly disagree',
#  'worklife_balance = Mildly agree',
#  'worklife_balance = Mildly disagree',
#  'worklife_balance = Moderately agree',
#  'worklife_balance = Moderately disagree',
#  'worklife_balance = Neither agree nor disagree',
#  'worklife_balance = Strongly agree',
#  'worklife_balance = Strongly disagree']

# %%
# See transformed data
te_df = pd.DataFrame(te_array, columns = te.columns_)

te_df
# Out:
#       Education = Primary/secondary school or technical/trade certificate or diploma  \
# 0                                                 False
# 1                                                 False
# 2                                                  True
# 3                                                  True
# 4                                                  True
# ...                                                 ...
# 4079                                              False
# 4080                                              False
# 4081                                               True
# 4082                                              False
# 4083                                              False
#
#       Education = University qualification  Salary = $ 110,000-159,999  \
# 0                                     True                        True
# 1                                     True                       False
# 2                                    False                       False
# 3                                    False                       False
# 4                                    False                       False
# ...                                    ...                         ...
# 4079                                  True                        True
# 4080                                  True                       False
# 4081                                 False                       False
# 4082                                  True                       False
# 4083                                  True                       False
#
#       Salary = $ 160,000 and over  Salary = $ 60,000-70,000  \
# 0                           False                     False
# 1                           False                     False
# 2                           False                     False
# 3                           False                      True
# 4                           False                      True
# ...                           ...                       ...
# 4079                        False                     False
# 4080                        False                      True
# 4081                        False                      True
# 4082                        False                     False
# 4083                        False                     False
#
#       Salary = $ 80,000-109,999  Salary = Less than $60,000  \
# 0                         False                       False
# 1                          True                       False
# 2                          True                       False
# 3                         False                       False
# 4                         False                       False
# ...                         ...                         ...
# 4079                      False                       False
# 4080                      False                       False
# 4081                      False                       False
# 4082                      False                        True
# 4083                       True                       False
#
#       career_development = Mildly agree  career_development = Mildly disagree  \
# 0                                  True                                 False
# 1                                 False                                 False
# 2                                 False                                 False
# 3                                 False                                 False
# 4                                 False                                 False
# ...                                 ...                                   ...
# 4079                              False                                 False
# 4080                               True                                 False
# 4081                              False                                 False
# 4082                              False                                  True
# 4083                              False                                 False
#
#       career_development = Moderately agree  ...  \
# 0                                     False  ...
# 1                                     False  ...
# 2                                     False  ...
# 3                                     False  ...
# 4                                     False  ...
# ...                                     ...  ...
# 4079                                  False  ...
# 4080                                  False  ...
# 4081                                  False  ...
# 4082                                  False  ...
# 4083                                  False  ...
#
#       well_managed = Neither agree nor disagree  \
# 0                                         False
# 1                                         False
# 2                                         False
# 3                                         False
# 4                                         False
# ...                                         ...
# 4079                                      False
# 4080                                      False
# 4081                                      False
# 4082                                      False
# 4083                                      False
#
#       well_managed = Strongly agree  well_managed = Strongly disagree  \
# 0                             False                             False
# 1                              True                             False
# 2                             False                              True
# 3                             False                              True
# 4                             False                             False
# ...                             ...                               ...
# 4079                          False                              True
# 4080                          False                             False
# 4081                          False                             False
# 4082                          False                             False
# 4083                          False                             False
#
#       worklife_balance = Mildly agree  worklife_balance = Mildly disagree  \
# 0                                True                               False
# 1                               False                               False
# 2                               False                               False
# 3                               False                               False
# 4                                True                               False
# ...                               ...                                 ...
# 4079                            False                               False
# 4080                             True                               False
# 4081                            False                                True
# 4082                            False                                True
# 4083                            False                               False
#
#       worklife_balance = Moderately agree  \
# 0                                   False
# 1                                   False
# 2                                    True
# 3                                   False
# 4                                   False
# ...                                   ...
# 4079                                False
# 4080                                False
# 4081                                False
# 4082                                False
# 4083                                False
#
#       worklife_balance = Moderately disagree  \
# 0                                      False
# 1                                      False
# 2                                      False
# 3                                      False
# 4                                      False
# ...                                      ...
# 4079                                   False
# 4080                                   False
# 4081                                   False
# 4082                                   False
# 4083                                   False
#
#       worklife_balance = Neither agree nor disagree  \
# 0                                             False
# 1                                             False
# 2                                             False
# 3                                             False
# 4                                             False
# ...                                             ...
# 4079                                          False
# 4080                                          False
# 4081                                          False
# 4082                                          False
# 4083                                          False
#
#       worklife_balance = Strongly agree  worklife_balance = Strongly disagree
# 0                                 False                                 False
# 1                                  True                                 False
# 2                                 False                                 False
# 3                                 False                                  True
# 4                                 False                                 False
# ...                                 ...                                   ...
# 4079                              False                                  True
# 4080                              False                                 False
# 4081                              False                                 False
# 4082                              False                                 False
# 4083                              False                                  True
#
# [4084 rows x 84 columns]

# %%
# Expanding table for clear view of item sets and association rules.

pd.set_option('display.max_colwidth', 1)

# %%
# Set minimum support threshold and show itemsets. Too many rules. Curse of dimensionality. 

freq_items = apriori(te_df, min_support = 0.03, use_colnames = True)
freq_items
# Out:
#        support  \
# 0     0.380999
# 1     0.619001
# 2     0.181929
# 3     0.033056
# 4     0.297013
# ...        ...
# 5501  0.034280
# 5502  0.031342
# 5503  0.032566
# 5504  0.033301
# 5505  0.030118
#
#                                                                                                                                                                                                                                                                                                                                                                                    itemsets
# 0     (Education = Primary/secondary school or technical/trade certificate or diploma)
# 1     (Education = University qualification)
# 2     (Salary = $ 110,000-159,999)
# 3     (Salary = $ 160,000 and over)
# 4     (Salary = $ 60,000-70,000)
# ...                          ...
# 5501  (ethical_practices = Strongly agree, level_of_skill_used = Strongly agree, conflicts_immediately_resolved = Strongly agree, effective_communication = Strongly agree, expectations_clarity = Strongly agree, good_relationship_with_coworkers = Strongly agree, contribution_recognition = Strongly agree, worklife_balance = Strongly agree, respectful_supervisor = Strongly agree)
# 5502  (ethical_practices = Strongly agree, conflicts_immediately_resolved = Strongly agree, effective_communication = Strongly agree, expectations_clarity = Strongly agree, good_relationship_with_coworkers = Strongly agree, contribution_recognition = Strongly agree, worklife_balance = Strongly agree, well_managed = Strongly agree, respectful_supervisor = Strongly agree)
# 5503  (ethical_practices = Strongly agree, level_of_skill_used = Strongly agree, conflicts_immediately_resolved = Strongly agree, expectations_clarity = Strongly agree, good_relationship_with_coworkers = Strongly agree, contribution_recognition = Strongly agree, worklife_balance = Strongly agree, well_managed = Strongly agree, respectful_supervisor = Strongly agree)
# 5504  (ethical_practices = Strongly agree, level_of_skill_used = Strongly agree, conflicts_immediately_resolved = Strongly agree, effective_communication = Strongly agree, expectations_clarity = Strongly agree, good_relationship_with_coworkers = Strongly agree, worklife_balance = Strongly agree, well_managed = Strongly agree, respectful_supervisor = Strongly agree)
# 5505  (ethical_practices = Strongly agree, level_of_skill_used = Strongly agree, effective_communication = Strongly agree, expectations_clarity = Strongly agree, good_relationship_with_coworkers = Strongly agree, contribution_recognition = Strongly agree, worklife_balance = Strongly agree, well_managed = Strongly agree, respectful_supervisor = Strongly agree)
#
# [5506 rows x 2 columns]

# %%
# If, then rules. Also setting minimum confidence thresholds

rules = association_rules(freq_items,metric='confidence',min_threshold=0.9)
rules[['antecedents','consequents','support','confidence','lift']]
# Out:
#                                                                                                                                                                                                                                            antecedents  \
# 0     (Salary = $ 160,000 and over)
# 1     (career_development = Strongly disagree, Salary = $ 110,000-159,999)
# 2     (Education = University qualification, effective_communication = Strongly agree)
# 3     (conflicts_immediately_resolved = Strongly agree, Salary = $ 110,000-159,999)
# 4     (good_relationship_with_coworkers = Strongly agree, Salary = $ 110,000-159,999)
# ...                                                                               ...
# 6657  (ethical_practices = Strongly agree, level_of_skill_used = Strongly agree, effective_communication = Strongly agree, contribution_recognition = Strongly agree, worklife_balance = Strongly agree, well_managed = Strongly agree)
# 6658  (level_of_skill_used = Strongly agree, effective_communication = Strongly agree, expectations_clarity = Strongly agree, contribution_recognition = Strongly agree, worklife_balance = Strongly agree, well_managed = Strongly agree)
# 6659  (level_of_skill_used = Strongly agree, effective_communication = Strongly agree, good_relationship_with_coworkers = Strongly agree, contribution_recognition = Strongly agree, worklife_balance = Strongly agree, well_managed = Strongly agree)
# 6660  (level_of_skill_used = Strongly agree, effective_communication = Strongly agree, contribution_recognition = Strongly agree, worklife_balance = Strongly agree, well_managed = Strongly agree, respectful_supervisor = Strongly agree)
# 6661  (level_of_skill_used = Strongly agree, effective_communication = Strongly agree, contribution_recognition = Strongly agree, worklife_balance = Strongly agree, well_managed = Strongly agree)
#
#                                                                                                                                                                  consequents  \
# 0     (Education = University qualification)
# 1     (Education = University qualification)
# 2     (respectful_supervisor = Strongly agree)
# 3     (ethical_practices = Strongly agree)
# 4     (respectful_supervisor = Strongly agree)
# ...                                        ...
# 6657  (good_relationship_with_coworkers = Strongly agree, respectful_supervisor = Strongly agree, expectations_clarity = Strongly agree)
# 6658  (ethical_practices = Strongly agree, respectful_supervisor = Strongly agree, good_relationship_with_coworkers = Strongly agree)
# 6659  (ethical_practices = Strongly agree, respectful_supervisor = Strongly agree, expectations_clarity = Strongly agree)
# 6660  (ethical_practices = Strongly agree, good_relationship_with_coworkers = Strongly agree, expectations_clarity = Strongly agree)
# 6661  (respectful_supervisor = Strongly agree, ethical_practices = Strongly agree, good_relationship_with_coworkers = Strongly agree, expectations_clarity = Strongly agree)
#
#        support  confidence      lift
# 0     0.031587  0.955556    1.543706
# 1     0.036239  0.925000    1.494343
# 2     0.082517  0.913279    1.786318
# 3     0.048237  0.903670    2.151946
# 4     0.081538  0.904891    1.769912
# ...        ...       ...         ...
# 6657  0.030118  0.931818    4.364158
# 6658  0.030118  0.946154    3.471781
# 6659  0.030118  0.968504    4.962823
# 6660  0.030118  0.924812    5.152704
# 6661  0.030118  0.917910    5.409446
#
# [6662 rows x 5 columns]

# %%
# Default value of display.max_rows is 10 i.e. at max 10 rows will be printed.
# Set it None to display all rows in the dataframe
pd.set_option('display.max_rows', 100)

# %%
rules.head(100)
# Out:
#                                                                                                                                                                              antecedents  \
# 0   (Salary = $ 160,000 and over)
# 1   (career_development = Strongly disagree, Salary = $ 110,000-159,999)
# 2   (Education = University qualification, effective_communication = Strongly agree)
# 3   (conflicts_immediately_resolved = Strongly agree, Salary = $ 110,000-159,999)
# 4   (good_relationship_with_coworkers = Strongly agree, Salary = $ 110,000-159,999)
# 5   (effective_communication = Strongly agree, Salary = $ 80,000-109,999)
# 6   (conflicts_immediately_resolved = Strongly agree, Salary = Less than $60,000)
# 7   (good_relationship_with_coworkers = Strongly agree, Salary = Less than $60,000)
# 8   (good_relationship_with_coworkers = Strongly agree, career_development = Mildly agree)
# 9   (conflicts_immediately_resolved = Strongly agree, career_development = Moderately agree)
# 10  (good_relationship_with_coworkers = Strongly agree, career_development = Moderately agree)
# 11  (conflicts_immediately_resolved = Strongly agree, career_development = Strongly agree)
# 12  (conflicts_immediately_resolved = Strongly agree, career_development = Strongly agree)
# 13  (career_development = Strongly agree, effective_communication = Strongly agree)
# 14  (career_development = Strongly agree, effective_communication = Strongly agree)
# 15  (ethical_practices = Strongly agree, career_development = Strongly agree)
# 16  (well_managed = Strongly agree, career_development = Strongly agree)
# 17  (good_relationship_with_coworkers = Strongly agree, career_development = Strongly agree)
# 18  (well_managed = Strongly agree, career_development = Strongly agree)
# 19  (career_development = Strongly agree, worklife_balance = Strongly agree)
# 20  (good_relationship_with_coworkers = Strongly agree, conflicts_immediately_resolved = Moderately agree)
# 21  (conflicts_immediately_resolved = Strongly agree, contribution_recognition = Strongly agree)
# 22  (conflicts_immediately_resolved = Strongly agree, contribution_recognition = Strongly agree)
# 23  (conflicts_immediately_resolved = Strongly agree, effective_communication = Strongly agree)
# 24  (conflicts_immediately_resolved = Strongly agree, effective_communication = Strongly agree)
# 25  (conflicts_immediately_resolved = Strongly agree, expectations_clarity = Strongly agree)
# 26  (good_relationship_with_coworkers = Strongly agree, conflicts_immediately_resolved = Strongly agree)
# 27  (conflicts_immediately_resolved = Strongly agree, level_of_skill_used = Strongly agree)
# 28  (respectful_supervisor = Strongly agree, conflicts_immediately_resolved = Strongly agree)
# 29  (well_managed = Moderately agree, conflicts_immediately_resolved = Strongly agree)
# 30  (well_managed = Strongly agree, conflicts_immediately_resolved = Strongly agree)
# 31  (conflicts_immediately_resolved = Strongly agree, worklife_balance = Strongly agree)
# 32  (good_relationship_with_coworkers = Strongly agree, conflicts_immediately_resolved = Strongly agree)
# 33  (well_managed = Strongly agree, conflicts_immediately_resolved = Strongly agree)
# 34  (good_relationship_with_coworkers = Strongly agree, contribution_recognition = Mildly agree)
# 35  (good_relationship_with_coworkers = Strongly agree, contribution_recognition = Moderately agree)
# 36  (effective_communication = Strongly agree, contribution_recognition = Strongly agree)
# 37  (ethical_practices = Strongly agree, contribution_recognition = Strongly agree)
# 38  (well_managed = Strongly agree, contribution_recognition = Strongly agree)
# 39  (good_relationship_with_coworkers = Strongly agree, contribution_recognition = Strongly agree)
# 40  (well_managed = Strongly agree, contribution_recognition = Strongly agree)
# 41  (contribution_recognition = Strongly agree, worklife_balance = Strongly agree)
# 42  (good_relationship_with_coworkers = Strongly agree, effective_communication = Mildly agree)
# 43  (effective_communication = Moderately agree, good_relationship_with_coworkers = Strongly agree)
# 44  (ethical_practices = Strongly agree, effective_communication = Strongly agree)
# 45  (well_managed = Strongly agree, effective_communication = Strongly agree)
# 46  (effective_communication = Strongly agree, expectations_clarity = Strongly agree)
# 47  (good_relationship_with_coworkers = Strongly agree, effective_communication = Strongly agree)
# 48  (effective_communication = Strongly agree, level_of_skill_used = Strongly agree)
# 49  (well_managed = Strongly agree, effective_communication = Strongly agree)
# 50  (effective_communication = Strongly agree, worklife_balance = Strongly agree)
# 51  (well_managed = Strongly agree, expectations_clarity = Strongly agree)
# 52  (ethical_practices = Strongly agree, good_relationship_with_coworkers = Strongly agree)
# 53  (well_managed = Strongly agree, good_relationship_with_coworkers = Strongly agree)
# 54  (well_managed = Strongly agree, level_of_skill_used = Strongly agree)
# 55  (well_managed = Strongly agree, ethical_practices = Strongly agree)
# 56  (well_managed = Strongly agree, respectful_supervisor = Strongly agree)
# 57  (well_managed = Strongly agree, worklife_balance = Strongly agree)
# 58  (good_relationship_with_coworkers = Strongly agree, expectations_clarity = Strongly agree)
# 59  (well_managed = Strongly agree, expectations_clarity = Strongly agree)
# 60  (good_relationship_with_coworkers = Strongly agree, level_of_skill_used = Strongly agree)
# 61  (good_relationship_with_coworkers = Strongly agree, well_managed = Mildly agree)
# 62  (well_managed = Moderately agree, good_relationship_with_coworkers = Strongly agree)
# 63  (well_managed = Strongly agree, good_relationship_with_coworkers = Strongly agree)
# 64  (worklife_balance = Moderately agree, good_relationship_with_coworkers = Strongly agree)
# 65  (good_relationship_with_coworkers = Strongly agree, worklife_balance = Strongly agree)
# 66  (well_managed = Strongly agree, level_of_skill_used = Strongly agree)
# 67  (well_managed = Strongly agree, worklife_balance = Strongly agree)
# 68  (good_relationship_with_coworkers = Strongly agree, Salary = Less than $60,000, Education = Primary/secondary school or technical/trade certificate or diploma)
# 69  (good_relationship_with_coworkers = Strongly agree, career_development = Moderately agree, Education = Primary/secondary school or technical/trade certificate or diploma)
# 70  (conflicts_immediately_resolved = Strongly agree, career_development = Strongly agree, Education = Primary/secondary school or technical/trade certificate or diploma)
# 71  (conflicts_immediately_resolved = Strongly agree, career_development = Strongly agree, Education = Primary/secondary school or technical/trade certificate or diploma)
# 72  (good_relationship_with_coworkers = Strongly agree, career_development = Strongly agree, Education = Primary/secondary school or technical/trade certificate or diploma)
# 73  (ethical_practices = Strongly agree, career_development = Strongly agree, Education = Primary/secondary school or technical/trade certificate or diploma)
# 74  (respectful_supervisor = Strongly agree, career_development = Strongly agree, Education = Primary/secondary school or technical/trade certificate or diploma)
# 75  (career_development = Strongly agree, Education = Primary/secondary school or technical/trade certificate or diploma, worklife_balance = Strongly agree)
# 76  (career_development = Strongly agree, expectations_clarity = Strongly agree, Education = Primary/secondary school or technical/trade certificate or diploma)
# 77  (good_relationship_with_coworkers = Strongly agree, career_development = Strongly agree, Education = Primary/secondary school or technical/trade certificate or diploma)
# 78  (career_development = Strongly agree, level_of_skill_used = Strongly agree, Education = Primary/secondary school or technical/trade certificate or diploma)
# 79  (career_development = Strongly agree, Education = Primary/secondary school or technical/trade certificate or diploma, worklife_balance = Strongly agree)
# 80  (conflicts_immediately_resolved = Strongly agree, contribution_recognition = Strongly agree, Education = Primary/secondary school or technical/trade certificate or diploma)
# 81  (conflicts_immediately_resolved = Strongly agree, contribution_recognition = Strongly agree, Education = Primary/secondary school or technical/trade certificate or diploma)
# 82  (conflicts_immediately_resolved = Strongly agree, effective_communication = Strongly agree, Education = Primary/secondary school or technical/trade certificate or diploma)
# 83  (conflicts_immediately_resolved = Strongly agree, effective_communication = Strongly agree, Education = Primary/secondary school or technical/trade certificate or diploma)
# 84  (conflicts_immediately_resolved = Strongly agree, expectations_clarity = Strongly agree, Education = Primary/secondary school or technical/trade certificate or diploma)
# 85  (good_relationship_with_coworkers = Strongly agree, conflicts_immediately_resolved = Strongly agree, Education = Primary/secondary school or technical/trade certificate or diploma)
# 86  (conflicts_immediately_resolved = Strongly agree, level_of_skill_used = Strongly agree, Education = Primary/secondary school or technical/trade certificate or diploma)
# 87  (respectful_supervisor = Strongly agree, conflicts_immediately_resolved = Strongly agree, Education = Primary/secondary school or technical/trade certificate or diploma)
# 88  (well_managed = Strongly agree, conflicts_immediately_resolved = Strongly agree, Education = Primary/secondary school or technical/trade certificate or diploma)
# 89  (conflicts_immediately_resolved = Strongly agree, Education = Primary/secondary school or technical/trade certificate or diploma, worklife_balance = Strongly agree)
# 90  (good_relationship_with_coworkers = Strongly agree, conflicts_immediately_resolved = Strongly agree, Education = Primary/secondary school or technical/trade certificate or diploma)
# 91  (conflicts_immediately_resolved = Strongly agree, level_of_skill_used = Strongly agree, Education = Primary/secondary school or technical/trade certificate or diploma)
# 92  (well_managed = Strongly agree, conflicts_immediately_resolved = Strongly agree, Education = Primary/secondary school or technical/trade certificate or diploma)
# 93  (good_relationship_with_coworkers = Strongly agree, contribution_recognition = Moderately agree, Education = Primary/secondary school or technical/trade certificate or diploma)
# 94  (ethical_practices = Strongly agree, contribution_recognition = Strongly agree, Education = Primary/secondary school or technical/trade certificate or diploma)
# 95  (good_relationship_with_coworkers = Strongly agree, contribution_recognition = Strongly agree, Education = Primary/secondary school or technical/trade certificate or diploma)
# 96  (level_of_skill_used = Strongly agree, contribution_recognition = Strongly agree, Education = Primary/secondary school or technical/trade certificate or diploma)
# 97  (Education = Primary/secondary school or technical/trade certificate or diploma, contribution_recognition = Strongly agree, worklife_balance = Strongly agree)
# 98  (effective_communication = Moderately agree, good_relationship_with_coworkers = Strongly agree, Education = Primary/secondary school or technical/trade certificate or diploma)
# 99  (ethical_practices = Strongly agree, effective_communication = Strongly agree, Education = Primary/secondary school or technical/trade certificate or diploma)
#
#                                  consequents  antecedent support  \
# 0   (Education = University qualification)    0.033056
# 1   (Education = University qualification)    0.039177
# 2   (respectful_supervisor = Strongly agree)  0.090353
# 3   (ethical_practices = Strongly agree)      0.053379
# 4   (respectful_supervisor = Strongly agree)  0.090108
# 5   (respectful_supervisor = Strongly agree)  0.042605
# 6   (ethical_practices = Strongly agree)      0.042116
# 7   (respectful_supervisor = Strongly agree)  0.060970
# 8   (respectful_supervisor = Strongly agree)  0.066112
# 9   (ethical_practices = Strongly agree)      0.061704
# 10  (respectful_supervisor = Strongly agree)  0.091577
# 11  (ethical_practices = Strongly agree)      0.078599
# 12  (respectful_supervisor = Strongly agree)  0.078599
# 13  (ethical_practices = Strongly agree)      0.057052
# 14  (respectful_supervisor = Strongly agree)  0.057052
# 15  (respectful_supervisor = Strongly agree)  0.091822
# 16  (ethical_practices = Strongly agree)      0.052889
# 17  (respectful_supervisor = Strongly agree)  0.086190
# 18  (respectful_supervisor = Strongly agree)  0.052889
# 19  (respectful_supervisor = Strongly agree)  0.072723
# 20  (respectful_supervisor = Strongly agree)  0.104554
# 21  (ethical_practices = Strongly agree)      0.095250
# 22  (respectful_supervisor = Strongly agree)  0.095250
# 23  (ethical_practices = Strongly agree)      0.097698
# 24  (respectful_supervisor = Strongly agree)  0.097698
# 25  (ethical_practices = Strongly agree)      0.166748
# 26  (ethical_practices = Strongly agree)      0.200049
# 27  (ethical_practices = Strongly agree)      0.139079
# 28  (ethical_practices = Strongly agree)      0.214006
# 29  (ethical_practices = Strongly agree)      0.092556
# 30  (ethical_practices = Strongly agree)      0.084476
# 31  (ethical_practices = Strongly agree)      0.136141
# 32  (respectful_supervisor = Strongly agree)  0.200049
# 33  (respectful_supervisor = Strongly agree)  0.084476
# 34  (respectful_supervisor = Strongly agree)  0.081783
# 35  (respectful_supervisor = Strongly agree)  0.107493
# 36  (respectful_supervisor = Strongly agree)  0.076396
# 37  (respectful_supervisor = Strongly agree)  0.121694
# 38  (ethical_practices = Strongly agree)      0.065622
# 39  (respectful_supervisor = Strongly agree)  0.123164
# 40  (respectful_supervisor = Strongly agree)  0.065622
# 41  (respectful_supervisor = Strongly agree)  0.099902
# 42  (respectful_supervisor = Strongly agree)  0.068315
# 43  (respectful_supervisor = Strongly agree)  0.129285
# 44  (respectful_supervisor = Strongly agree)  0.119980
# 45  (ethical_practices = Strongly agree)      0.066601
# 46  (respectful_supervisor = Strongly agree)  0.110676
# 47  (respectful_supervisor = Strongly agree)  0.121694
# 48  (respectful_supervisor = Strongly agree)  0.096474
# 49  (respectful_supervisor = Strongly agree)  0.066601
# 50  (respectful_supervisor = Strongly agree)  0.093536
# 51  (ethical_practices = Strongly agree)      0.093536
# 52  (respectful_supervisor = Strongly agree)  0.291136
# 53  (ethical_practices = Strongly agree)      0.093536
# 54  (ethical_practices = Strongly agree)      0.084476
# 55  (respectful_supervisor = Strongly agree)  0.103330
# 56  (ethical_practices = Strongly agree)      0.102840
# 57  (ethical_practices = Strongly agree)      0.081048
# 58  (respectful_supervisor = Strongly agree)  0.229922
# 59  (respectful_supervisor = Strongly agree)  0.093536
# 60  (respectful_supervisor = Strongly agree)  0.185357
# 61  (respectful_supervisor = Strongly agree)  0.072723
# 62  (respectful_supervisor = Strongly agree)  0.124388
# 63  (respectful_supervisor = Strongly agree)  0.093536
# 64  (respectful_supervisor = Strongly agree)  0.121694
# 65  (respectful_supervisor = Strongly agree)  0.179481
# 66  (respectful_supervisor = Strongly agree)  0.084476
# 67  (respectful_supervisor = Strongly agree)  0.081048
# 68  (respectful_supervisor = Strongly agree)  0.036974
# 69  (respectful_supervisor = Strongly agree)  0.034280
# 70  (ethical_practices = Strongly agree)      0.035504
# 71  (respectful_supervisor = Strongly agree)  0.035504
# 72  (ethical_practices = Strongly agree)      0.037218
# 73  (respectful_supervisor = Strongly agree)  0.041626
# 74  (ethical_practices = Strongly agree)      0.042605
# 75  (ethical_practices = Strongly agree)      0.032321
# 76  (respectful_supervisor = Strongly agree)  0.037218
# 77  (respectful_supervisor = Strongly agree)  0.037218
# 78  (respectful_supervisor = Strongly agree)  0.039422
# 79  (respectful_supervisor = Strongly agree)  0.032321
# 80  (ethical_practices = Strongly agree)      0.039177
# 81  (respectful_supervisor = Strongly agree)  0.039177
# 82  (ethical_practices = Strongly agree)      0.043095
# 83  (respectful_supervisor = Strongly agree)  0.043095
# 84  (ethical_practices = Strongly agree)      0.073213
# 85  (ethical_practices = Strongly agree)      0.081048
# 86  (ethical_practices = Strongly agree)      0.061459
# 87  (ethical_practices = Strongly agree)      0.089373
# 88  (ethical_practices = Strongly agree)      0.033546
# 89  (ethical_practices = Strongly agree)      0.058276
# 90  (respectful_supervisor = Strongly agree)  0.081048
# 91  (respectful_supervisor = Strongly agree)  0.061459
# 92  (respectful_supervisor = Strongly agree)  0.033546
# 93  (respectful_supervisor = Strongly agree)  0.041381
# 94  (respectful_supervisor = Strongly agree)  0.048482
# 95  (respectful_supervisor = Strongly agree)  0.047258
# 96  (respectful_supervisor = Strongly agree)  0.043340
# 97  (respectful_supervisor = Strongly agree)  0.039177
# 98  (respectful_supervisor = Strongly agree)  0.047747
# 99  (respectful_supervisor = Strongly agree)  0.050930
#
#     consequent support   support  confidence      lift  leverage  conviction
# 0   0.619001            0.031587  0.955556    1.543706  0.011125  8.572478
# 1   0.619001            0.036239  0.925000    1.494343  0.011988  5.079987
# 2   0.511263            0.082517  0.913279    1.786318  0.036323  5.635743
# 3   0.419931            0.048237  0.903670    2.151946  0.025821  6.021664
# 4   0.511263            0.081538  0.904891    1.769912  0.035469  5.138716
# 5   0.511263            0.039912  0.936782    1.832287  0.018129  7.730923
# 6   0.419931            0.037953  0.901163    2.145976  0.020267  5.868929
# 7   0.511263            0.056072  0.919679    1.798835  0.024901  6.084770
# 8   0.511263            0.059745  0.903704    1.767589  0.025945  5.075341
# 9   0.419931            0.056807  0.920635    2.192346  0.030896  7.308864
# 10  0.511263            0.088149  0.962567    1.882722  0.041329  13.056247
# 11  0.419931            0.073947  0.940810    2.240389  0.040941  9.800106
# 12  0.511263            0.073457  0.934579    1.827980  0.033272  7.470687
# 13  0.419931            0.052644  0.922747    2.197375  0.028687  7.508665
# 14  0.511263            0.055583  0.974249    1.905571  0.026414  18.979269
# 15  0.511263            0.084476  0.920000    1.799464  0.037531  6.109207
# 16  0.419931            0.049706  0.939815    2.238020  0.027496  9.638062
# 17  0.511263            0.083497  0.968750    1.894816  0.039431  15.639569
# 18  0.511263            0.050196  0.949074    1.856331  0.023156  9.597008
# 19  0.511263            0.068805  0.946128    1.850568  0.031625  9.072172
# 20  0.511263            0.096474  0.922717    1.804777  0.043019  6.323955
# 21  0.419931            0.090353  0.948586    2.258907  0.050354  11.282333
# 22  0.511263            0.089373  0.938303    1.835264  0.040675  7.921605
# 23  0.419931            0.093046  0.952381    2.267944  0.052019  12.181440
# 24  0.511263            0.092801  0.949875    1.857897  0.042852  9.750294
# 25  0.419931            0.153526  0.920705    2.192512  0.083503  7.315309
# 26  0.419931            0.185113  0.925337    2.203542  0.101106  7.769115
# 27  0.419931            0.129775  0.933099    2.222026  0.071371  8.670498
# 28  0.419931            0.195886  0.915332    2.179717  0.106019  6.851080
# 29  0.419931            0.083741  0.904762    2.154547  0.044874  6.090720
# 30  0.419931            0.081783  0.968116    2.305414  0.046308  18.193059
# 31  0.419931            0.128795  0.946043    2.252851  0.071625  10.750604
# 32  0.511263            0.190500  0.952264    1.862571  0.088222  10.238404
# 33  0.511263            0.079089  0.936232    1.831212  0.035900  7.664277
# 34  0.511263            0.074437  0.910180    1.780256  0.032624  5.441267
# 35  0.511263            0.101371  0.943052    1.844553  0.046414  8.582214
# 36  0.511263            0.073213  0.958333    1.874441  0.034154  11.729677
# 37  0.511263            0.112880  0.927565    1.814261  0.050662  6.747279
# 38  0.419931            0.060480  0.921642    2.194743  0.032923  7.402780
# 39  0.511263            0.119001  0.966203    1.889833  0.056032  14.460852
# 40  0.511263            0.060970  0.929104    1.817271  0.027420  6.893757
# 41  0.511263            0.092556  0.926471    1.812120  0.041480  6.646817
# 42  0.511263            0.061704  0.903226    1.766654  0.026777  5.050278
# 43  0.511263            0.122429  0.946970    1.852215  0.056330  9.216175
# 44  0.511263            0.112145  0.934694    1.828204  0.050803  7.483778
# 45  0.419931            0.062194  0.933824    2.223752  0.034226  8.765480
# 46  0.511263            0.102840  0.929204    1.817465  0.046256  6.903404
# 47  0.511263            0.119736  0.983903    1.924455  0.057518  30.362757
# 48  0.511263            0.089373  0.926396    1.811974  0.040050  6.640076
# 49  0.511263            0.062439  0.937500    1.833693  0.028388  7.819785
# 50  0.511263            0.087659  0.937173    1.833052  0.039838  7.779056
# 51  0.419931            0.084721  0.905759    2.156922  0.045442  6.155172
# 52  0.511263            0.272527  0.936081    1.830917  0.123680  7.646154
# 53  0.419931            0.088639  0.947644    2.256664  0.049360  11.079310
# 54  0.419931            0.076641  0.907246    2.160463  0.041166  6.253864
# 55  0.511263            0.095250  0.921801    1.802986  0.042421  6.249904
# 56  0.419931            0.095250  0.926190    2.205575  0.052064  7.858993
# 57  0.419931            0.075416  0.930514    2.215870  0.041382  8.347943
# 58  0.511263            0.213516  0.928647    1.816378  0.095966  6.849606
# 59  0.511263            0.084966  0.908377    1.776730  0.037144  5.334210
# 60  0.511263            0.176787  0.953765    1.865506  0.082021  10.570673
# 61  0.511263            0.066112  0.909091    1.778126  0.028931  5.376102
# 62  0.511263            0.117532  0.944882    1.848131  0.053937  8.867077
# 63  0.511263            0.090353  0.965969    1.889375  0.042531  14.361335
# 64  0.511263            0.112880  0.927565    1.814261  0.050662  6.747279
# 65  0.511263            0.172625  0.961801    1.881223  0.080863  12.794424
# 66  0.511263            0.076885  0.910145    1.780188  0.033696  5.439165
# 67  0.511263            0.075416  0.930514    1.820028  0.033979  7.033556
# 68  0.511263            0.035015  0.947020    1.852313  0.016111  9.224902
# 69  0.511263            0.033790  0.985714    1.927997  0.016264  34.211557
# 70  0.419931            0.034035  0.958621    2.282803  0.019126  14.018324
# 71  0.511263            0.033301  0.937931    1.834536  0.015149  7.874089
# 72  0.419931            0.034280  0.921053    2.193340  0.018651  7.347535
# 73  0.511263            0.038932  0.935294    1.829378  0.017651  7.553201
# 74  0.419931            0.038932  0.913793    2.176053  0.021041  6.728795
# 75  0.419931            0.030118  0.931818    2.218977  0.016545  8.507672
# 76  0.511263            0.033546  0.901316    1.762918  0.014517  4.952530
# 77  0.511263            0.035749  0.960526    1.878731  0.016721  12.381325
# 78  0.511263            0.035749  0.906832    1.773708  0.015594  5.245772
# 79  0.511263            0.030852  0.954545    1.867032  0.014327  10.752204
# 80  0.419931            0.037708  0.962500    2.292041  0.021256  15.468495
# 81  0.511263            0.037218  0.950000    1.858142  0.017189  9.774731
# 82  0.419931            0.041381  0.960227    2.286629  0.023284  14.584581
# 83  0.511263            0.040157  0.931818    1.822579  0.018124  7.168136
# 84  0.419931            0.067581  0.923077    2.198161  0.036837  7.540891
# 85  0.419931            0.075171  0.927492    2.208676  0.041137  8.000112
# 86  0.419931            0.057786  0.940239    2.239030  0.031978  9.706481
# 87  0.419931            0.080803  0.904110    2.152993  0.043273  6.049286
# 88  0.419931            0.032811  0.978102    2.329195  0.018724  26.489798
# 89  0.419931            0.055093  0.945378    2.251268  0.030621  10.619717
# 90  0.511263            0.078599  0.969789    1.896847  0.037163  16.177179
# 91  0.511263            0.055338  0.900398    1.761124  0.023916  4.906915
# 92  0.511263            0.031587  0.941606    1.841723  0.014436  8.369613
# 93  0.511263            0.039177  0.946746    1.851776  0.018021  9.177386
# 94  0.511263            0.046033  0.949495    1.857154  0.021246  9.676983
# 95  0.511263            0.045788  0.968912    1.895132  0.021627  15.721025
# 96  0.511263            0.039912  0.920904    1.801232  0.017754  6.179026
# 97  0.511263            0.036729  0.937500    1.833693  0.016699  7.819785
# 98  0.511263            0.045054  0.943590    1.845604  0.020642  8.663966
# 99  0.511263            0.047258  0.927885    1.814885  0.021219  6.777147
